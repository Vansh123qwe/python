# %%
def funct(vansh):
    a=[1,2,3,4,5]
    print(a)

# %%
funct(vansh)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cefebf9152c8> in <module>
# ----> 1 funct(vansh)
#
# NameError: name 'vansh' is not defined

# %%
funct(vansh):
# Out:
#   File "<ipython-input-3-22eb195219c9>", line 1
#     funct(vansh):
#                  ^
# SyntaxError: invalid syntax

# %%
funct(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a839d0027760> in <module>
# ----> 1 funct(a)
#
# NameError: name 'a' is not defined

# %%
a=[1,2,3,4,5]

# %%
def fun(b):
    print(b)

# %%
fun(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
vansh(12+34)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-849e7efa25bd> in <module>
# ----> 1 vansh(12+34)
#
# <ipython-input-8-344d63b9e2e8> in vansh(t)
#       1 def vansh(t):
# ----> 2     print(c+d)
#
# NameError: name 'c' is not defined

# %%
vansh(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8ec2f6191c96> in <module>
# ----> 1 vansh(t)
#
# NameError: name 't' is not defined

# %%
def vansh(t):
    c=34
    d=45
    print(c+d)

# %%
c+d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ad687b5fa348> in <module>
# ----> 1 c+d
#
# NameError: name 'c' is not defined

# %%
c=34
    def vansh(t):
          print(c+d)
# Out:
#   File "<ipython-input-16-8d036317773c>", line 2
#     def vansh(t):
#     ^
# IndentationError: unexpected indent

# %%
f=45
def funny(i):
    print(i)

# %%
f=45
def funny(i):
    print(i)
# Out:
# 45

# %%
import threading

# %%
if __name__=='__main__':
# Out:
#   File "<ipython-input-32-bde64a4f94ac>", line 1
#     if __name__=='__main__':
#                             ^
# SyntaxError: unexpected EOF while parsing

# %%
if __name__=='__main__':
# Out:
#   File "<ipython-input-27-bde64a4f94ac>", line 1
#     if __name__=='__main__':
#                             ^
# SyntaxError: unexpected EOF while parsing

# %%
if __name__=='__main__':
    t1= threading.Thread(target = funny,args=(5,))
    t2= threading.Thread(target = fun,args=(4,))
    t1.start()
    t2.start()
    t1.join()
    t2.join()
# Out:
# 5
# 4

# %%
v=[2,3,4,5,6,7]

for y in v:
    if(y == 3):
        print(y)
            
        try:
            a=5
            b=4

            
            if(a>b):
                print("thisb is wrong")
        except:
            print("this is right")
        finally:
            print("try again")
            
            if __name__=='__main__':
                t1= threading.Thread(target = funny,args=(5,))
                t2= threading.Thread(target = fun,args=(4,))
                t1.start()
                t2.start()
                t1.join()
                t2.join()
            
f=open("abc.txt",'w')
f.write("hi vansh how r u")
        
f=open("abc.txt",'a')
f=open("abc.txt",'r')
        
f.read()

import webbrowser as wb
a=input("Enter your search term")

wb.open_new_tab("https://www.google.com/search?ei=S5ETXbGgL4ib9QPHlIaQAg&q=%s"%a)
# Out:
# 3
# thisb is wrong
# try again
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3e2b01a2e102> in <module>
#      18
#      19             if __name__=='__main__':
# ---> 20                 t1= threading.Thread(target = funny,args=(5,))
#      21                 t2= threading.Thread(target = fun,args=(4,))
#      22                 t1.start()
#
# NameError: name 'funny' is not defined

# %%
import beautifulsoop
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-618b285cf8a2> in <module>
# ----> 1 import beautifulsoop
#
# ModuleNotFoundError: No module named 'beautifulsoop'

# %%
from bs4 import Beautifulsoup
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-eab54f05eca9> in <module>
# ----> 1 from bs4 import Beautifulsoup
#
# ImportError: cannot import name 'Beautifulsoup' from 'bs4' (C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py)

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %% [raw]
# url= requests.get('https://www.google.com/search?ei=CzMXXZy1MtGhyAPxqKjACQ&q=gmail')

# %%
url= requests.get('https://www.cricbuzz.com')

# %%
print(url)
# Out:
# <Response [200]>

# %%
url.text
# Out:
# '\r\n\r\n<!DOCTYPE html><html lang="en" itemscope itemtype="http://schema.org/WebPage"><head><meta charset="utf-8"><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);\tif(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}\tbody, .cb-comm-pg, .cb-hm-mid {min-height:1000px}\t.container{width:980px;margin:0 auto;}\t.page{max-width: 980px;margin: 0 auto;position: relative;}\t.cb-col-8 {width:8%;}\t.cb-col-10 {width:10%;}\t.cb-col-14 {width:14%;}\t.cb-col-16 {width:16%;}\t.cb-col-20 {width:20%;}\t.cb-col-25 {width:25%;}\t.cb-col-27 {width:27%;}\t.cb-col-33 {width:33%;}\t.cb-col-40 {width:40%;}\t.cb-col-46 {width:46%;}\t.cb-col-47 {width:47%;}\t.cb-col-50 {width:50%;}\t.cb-col-60 {width:60%;}\t.cb-col-66 {width:66%;}\t.cb-co
# ...

# %%
Soup=url.text

# %%
s=BeautifulSoup(Soup,'html.parser')

# %%
print(s)
# Out:
# <!DOCTYPE html>
# ...

# %%
for i in s.find_all("div",{"class":'cb-col cb-col-100'}):
    i.text

# %%
print(i.text)
# Out:
# FeaturedInternationalICC Cricket WC 2019PAK U19 tour of SAAll MatchesAFG77/3 (14.4 Ovs)PAKAfghanistan opt to batEngland IndiaNew Zealand AustraliaRSA206/1 (37.2 Ovs)SL203 (49.3 Ovs)South Africa won by 9 wktsAFG77/3 (14.4 Ovs)PAKAfghanistan opt to batEngland IndiaNew Zealand AustraliaRSA206/1 (37.2 Ovs)SL203 (49.3 Ovs)South Africa won by 9 wktsAFG77/3 (14.4 Ovs)PAKAfghanistan opt to batEngland IndiaNew Zealand AustraliaRSA206/1 (37.2 Ovs)SL203 (49.3 Ovs)South Africa won by 9 wktsSouth Africa U19 Pakistan U19

# %%
for i in s.find_all("div",{"class":'cb-col-67.cb-col.cb-left.cb-schdl'}):
    i.text

# %%
print(i.text)
# Out:
# FeaturedInternationalICC Cricket WC 2019PAK U19 tour of SAAll MatchesAFG77/3 (14.4 Ovs)PAKAfghanistan opt to batEngland IndiaNew Zealand AustraliaRSA206/1 (37.2 Ovs)SL203 (49.3 Ovs)South Africa won by 9 wktsAFG77/3 (14.4 Ovs)PAKAfghanistan opt to batEngland IndiaNew Zealand AustraliaRSA206/1 (37.2 Ovs)SL203 (49.3 Ovs)South Africa won by 9 wktsAFG77/3 (14.4 Ovs)PAKAfghanistan opt to batEngland IndiaNew Zealand AustraliaRSA206/1 (37.2 Ovs)SL203 (49.3 Ovs)South Africa won by 9 wktsSouth Africa U19 Pakistan U19

# %%
for i in s.find_all("div",{"class":'cb-mtch-lst cb-col cb-col-100 cb-schd1'}):
    i.text

# %%
print(i.text)
# Out:
# FeaturedInternationalICC Cricket WC 2019PAK U19 tour of SAAll MatchesAFG77/3 (14.4 Ovs)PAKAfghanistan opt to batEngland IndiaNew Zealand AustraliaRSA206/1 (37.2 Ovs)SL203 (49.3 Ovs)South Africa won by 9 wktsAFG77/3 (14.4 Ovs)PAKAfghanistan opt to batEngland IndiaNew Zealand AustraliaRSA206/1 (37.2 Ovs)SL203 (49.3 Ovs)South Africa won by 9 wktsAFG77/3 (14.4 Ovs)PAKAfghanistan opt to batEngland IndiaNew Zealand AustraliaRSA206/1 (37.2 Ovs)SL203 (49.3 Ovs)South Africa won by 9 wktsSouth Africa U19 Pakistan U19

# %%
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-beb514e823a4> in <module>
# ----> 1 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'
